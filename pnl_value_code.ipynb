# %%
#Xin cấp quyền máy ảo chạy vào GG drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
pnl_sample_df = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/PnL.xlsx',sheet_name='pnl_sample')
pnl_sample_df.head()
#Fill NaN by ' '
pnl_sample_df.fillna('', inplace=True)
pnl_sample_df.head()
# Out:
# <ipython-input-3-bfc0f7b94ba0>:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   pnl_sample_df.fillna('', inplace=True)
#    Mã số                                           Chỉ tiêu Thuyết minh  \
# 0      1          1. Doanh thu bán hàng và cung cấp dịch vụ       VI.25
# 1      2                    2. Các khoản giảm trừ doanh thu
# 2     10  3. Doanh thu thuần về bán hàng và cung cấp dịc...
# 3     11                                4. Gía vốn hàng bán       VI.27
# 4     20  5. Lợi nhuận gộp từ bán hàng và cung cấp dịch ...
#
#   Kỳ này Kỳ trước Lũy kế(Năm nay) Lũy kế(Năm trước)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **Quý trong năm 2021**

# %%
quarter_2021_df = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/PnL.xlsx',sheet_name='year 2021')
quarter_2021_df.head()
# Out:
#                                             Chỉ tiêu   Quý 1- 2021  \
# 0          1. Doanh thu bán hàng và cung cấp dịch vụ  3.590063e+11
# 1                    2. Các khoản giảm trừ doanh thu           NaN
# 2  3. Doanh thu thuần về bán hàng và cung cấp dịc...  3.590063e+11
# 3                                4. Giá vốn hàng bán  2.622358e+11
# 4  5. Lợi nhuận gộp về bán hàng và cung cấp dịch ...  9.677055e+10
#
#     Quý 2- 2021   Quý 3- 2021   Quý 4- 2021
# 0  4.492668e+11  4.756049e+11  6.714234e+11
# 1           NaN           NaN           NaN
# 2  4.492668e+11  4.756049e+11  6.714234e+11
# 3  3.079875e+11  3.357696e+11  3.348648e+11
# 4  1.412793e+11  1.398353e+11  3.365587e+11

# %%
#pnl_20210331
pnl_sample_df['Kỳ này']=quarter_2021_df['Quý 1- 2021']
pnl_20210331 = pnl_sample_df.copy()
pnl_20210331.head()
#pnl_20210630
pnl_sample_df['Kỳ này']=quarter_2021_df['Quý 2- 2021']
pnl_20210630 = pnl_sample_df.copy()
#pnl_20210930
pnl_sample_df['Kỳ này']=quarter_2021_df['Quý 3- 2021']
pnl_20210930 = pnl_sample_df.copy()
#pnl_20211231
pnl_sample_df['Kỳ này']=quarter_2021_df['Quý 4- 2021']
pnl_20211231 = pnl_sample_df.copy()

# %% [markdown]
# **Quý trong năm 2022**

# %%
quarter_2022_df = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/PnL.xlsx',sheet_name='year 2022')
quarter_2022_df.head()
# Out:
#                                             Chỉ tiêu   Quý 1- 2022  \
# 0          1. Doanh thu bán hàng và cung cấp dịch vụ  6.524512e+11
# 1                    2. Các khoản giảm trừ doanh thu           NaN
# 2  3. Doanh thu thuần về bán hàng và cung cấp dịc...  6.524512e+11
# 3                                4. Giá vốn hàng bán  3.124711e+11
# 4  5. Lợi nhuận gộp về bán hàng và cung cấp dịch ...  3.399801e+11
#
#     Quý 2- 2022   Quý 3- 2022   Quý 4- 2022
# 0  9.292210e+11  7.785723e+11  8.453655e+11
# 1           NaN           NaN           NaN
# 2  9.292210e+11  7.785723e+11  8.453655e+11
# 3  4.952052e+11  4.016990e+11  5.744898e+11
# 4  4.340158e+11  3.768733e+11  2.708757e+11

# %%
#pnl_20220331
pnl_sample_df['Kỳ này']=quarter_2022_df['Quý 1- 2022']
pnl_20220331 = pnl_sample_df.copy()
#pnl_20220630
pnl_sample_df['Kỳ này']=quarter_2022_df['Quý 2- 2022']
pnl_20220630 = pnl_sample_df.copy()
#pnl_20220930
pnl_sample_df['Kỳ này']=quarter_2022_df['Quý 3- 2022']
pnl_20220930 = pnl_sample_df.copy()
#pnl_20221231
pnl_sample_df['Kỳ này']=quarter_2022_df['Quý 4- 2022']
pnl_20221231 = pnl_sample_df.copy()
pnl_20221231.head()
# Out:
#    Mã số                                           Chỉ tiêu Thuyết minh  \
# 0      1          1. Doanh thu bán hàng và cung cấp dịch vụ       VI.25
# 1      2                    2. Các khoản giảm trừ doanh thu
# 2     10  3. Doanh thu thuần về bán hàng và cung cấp dịc...
# 3     11                                4. Gía vốn hàng bán       VI.27
# 4     20  5. Lợi nhuận gộp từ bán hàng và cung cấp dịch ...
#
#          Kỳ này Kỳ trước Lũy kế(Năm nay) Lũy kế(Năm trước)
# 0  8.453655e+11
# 1           NaN
# 2  8.453655e+11
# 3  5.744898e+11
# 4  2.708757e+11

# %% [markdown]
# **Quý trong năm 2023**

# %%
quarter_2023_df = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/PnL.xlsx',sheet_name='year 2023')
quarter_2023_df.head()
# Out:
#                                             Chỉ tiêu   Quý 1- 2023  \
# 0          1. Doanh thu bán hàng và cung cấp dịch vụ  6.551415e+11
# 1                    2. Các khoản giảm trừ doanh thu           NaN
# 2  3. Doanh thu thuần về bán hàng và cung cấp dịc...  6.551415e+11
# 3                                4. Giá vốn hàng bán  4.626867e+11
# 4  5. Lợi nhuận gộp về bán hàng và cung cấp dịch ...  1.924548e+11
#
#     Quý 2- 2023   Quý 3- 2023   Quý 4- 2023
# 0  6.114235e+11  6.813604e+11  6.647643e+11
# 1           NaN           NaN           NaN
# 2  6.114235e+11  6.813604e+11  6.647643e+11
# 3  4.642443e+11  5.231369e+11  5.516168e+11
# 4  1.471792e+11  1.582236e+11  1.131475e+11

# %%
#pnl_20230331
pnl_sample_df['Kỳ này']=quarter_2023_df['Quý 1- 2023']
pnl_20230331 = pnl_sample_df.copy()
#pnl_20230630
pnl_sample_df['Kỳ này']=quarter_2023_df['Quý 2- 2023']
pnl_20230630 = pnl_sample_df.copy()
#pnl_20220930
pnl_sample_df['Kỳ này']=quarter_2023_df['Quý 3- 2023']
pnl_20230930 = pnl_sample_df.copy()
#pnl_20221231
pnl_sample_df['Kỳ này']=quarter_2023_df['Quý 4- 2023']
pnl_20231231 = pnl_sample_df.copy()
pnl_20231231.head()
# Out:
#    Mã số                                           Chỉ tiêu Thuyết minh  \
# 0      1          1. Doanh thu bán hàng và cung cấp dịch vụ       VI.25
# 1      2                    2. Các khoản giảm trừ doanh thu
# 2     10  3. Doanh thu thuần về bán hàng và cung cấp dịc...
# 3     11                                4. Gía vốn hàng bán       VI.27
# 4     20  5. Lợi nhuận gộp từ bán hàng và cung cấp dịch ...
#
#          Kỳ này Kỳ trước Lũy kế(Năm nay) Lũy kế(Năm trước)
# 0  6.647643e+11
# 1           NaN
# 2  6.647643e+11
# 3  5.516168e+11
# 4  1.131475e+11

# %% [markdown]
# **Quý trong năm 2024**

# %%
quarter_2024_df = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/PnL.xlsx',sheet_name='year 2024')
quarter_2024_df.head()
# Out:
#                                             Chỉ tiêu   Quý 1- 2024  \
# 0          1. Doanh thu bán hàng và cung cấp dịch vụ  7.041011e+11
# 1                    2. Các khoản giảm trừ doanh thu           NaN
# 2  3. Doanh thu thuần về bán hàng và cung cấp dịc...  7.041011e+11
# 3                                4. Giá vốn hàng bán  5.978567e+11
# 4  5. Lợi nhuận gộp về bán hàng và cung cấp dịch ...  1.062444e+11
#
#     Quý 2- 2024
# 0  9.487856e+11
# 1           NaN
# 2  9.487856e+11
# 3  6.988943e+11
# 4  2.498913e+11

# %%
#pnl_20240331
pnl_sample_df['Kỳ này']=quarter_2024_df['Quý 1- 2024']
pnl_20240331 = pnl_sample_df.copy()
#pnl_20240631
pnl_sample_df['Kỳ này']=quarter_2024_df['Quý 2- 2024']
pnl_20240630 = pnl_sample_df.copy()
pnl_20240630.head()
# Out:
#    Mã số                                           Chỉ tiêu Thuyết minh  \
# 0      1          1. Doanh thu bán hàng và cung cấp dịch vụ       VI.25
# 1      2                    2. Các khoản giảm trừ doanh thu
# 2     10  3. Doanh thu thuần về bán hàng và cung cấp dịc...
# 3     11                                4. Gía vốn hàng bán       VI.27
# 4     20  5. Lợi nhuận gộp từ bán hàng và cung cấp dịch ...
#
#          Kỳ này Kỳ trước Lũy kế(Năm nay) Lũy kế(Năm trước)
# 0  9.487856e+11
# 1           NaN
# 2  9.487856e+11
# 3  6.988943e+11
# 4  2.498913e+11

# %%
#Lưu vào file excel
pnl_20210331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20210331.xlsx',index=False)
pnl_20210630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20210630.xlsx',index=False)
pnl_20210930.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20210930.xlsx',index=False)
pnl_20211231.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20211231.xlsx',index=False)
pnl_20220331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20220331.xlsx',index=False)
pnl_20220630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20220630.xlsx',index=False)
pnl_20220930.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20220930.xlsx',index=False)
pnl_20221231.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20221231.xlsx',index=False)
pnl_20230331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20230331.xlsx',index=False)
pnl_20230630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20230630.xlsx',index=False)
pnl_20230930.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20230930.xlsx',index=False)
pnl_20231231.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20231231.xlsx',index=False)
pnl_20240331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20240331.xlsx',index=False)
pnl_20240630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Báo cáo kết quả hoạt động kinh doanh/pnl_20240630.xlsx',index=False)
