# %%
#Xin cấp quyền máy ảo chạy vào GG drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
sample_df = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/sample.xlsx',sheet_name='account')
#fill NaN by ' '
sample_df = sample_df.fillna('')
sample_df.head()
# Out:
#                                        Chỉ tiêu Mã số Số cuối kỳ Số đầu kỳ
# 0  A.Tài sản ngắn hạn (100=110+120+130+140+150)   100
# 1         I. Tiền và các khoản tương đương tiền   110
# 2                                       1. Tiền   111
# 3                 2. Các khoản tương đương tiền   112
# 4       II. Các khoản đầu tư tài chính ngắn hạn   120

# %% [markdown]
# **Quý 1, Quý 2 năm 2021**

# %%
Q1_Q2_2021 = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/sample.xlsx',sheet_name='Q1 to Q2 2021')
Q1_Q2_2021.head()
# Out:
#                                    TÀI SẢN   Quý 1- 2021   Quý 2- 2021
# 0                      A- TÀI SẢN NGẮN HẠN  8.773437e+11  7.647396e+11
# 1    I. Tiền và các khoản tương đương tiền  3.446877e+11  2.234443e+11
# 2                                  1. Tiền  2.380989e+11  1.678443e+11
# 3            2. Các khoản tương đương tiền  1.065888e+11  5.560000e+10
# 4  II. Các khoản đầu tư tài chính ngắn hạn  7.865525e+10  6.134174e+10

# %%
#cdkt_20210331
sample_df['Số cuối kỳ'] = Q1_Q2_2021['Quý 1- 2021']
cdkt_20210331 = sample_df.copy()
cdkt_20210331.head()
#cdkt_20210630
sample_df['Số cuối kỳ'] = Q1_Q2_2021['Quý 2- 2021']
cdkt_20210630 = sample_df.copy()
cdkt_20210630.head()
# Out:
#                                        Chỉ tiêu Mã số    Số cuối kỳ Số đầu kỳ
# 0  A.Tài sản ngắn hạn (100=110+120+130+140+150)   100  7.647396e+11
# 1         I. Tiền và các khoản tương đương tiền   110  2.234443e+11
# 2                                       1. Tiền   111  1.678443e+11
# 3                 2. Các khoản tương đương tiền   112  5.560000e+10
# 4       II. Các khoản đầu tư tài chính ngắn hạn   120  6.134174e+10

# %% [markdown]
# **Quý 3, Quý 4 năm 2021; Quý 1, Quý 2 năm 2022**

# %%
Q3_2021_to_Q2_2022 = pd.read_excel ('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/sample.xlsx',sheet_name='Q3-2021 to Q2-2022')
Q3_2021_to_Q2_2022.head()
# Out:
#                                    TÀI SẢN   Quý 3- 2021   Quý 4- 2021  \
# 0                      A- TÀI SẢN NGẮN HẠN  8.892372e+11  1.287238e+12
# 1    I. Tiền và các khoản tương đương tiền  2.171378e+11  4.847324e+11
# 2                                  1. Tiền  1.631053e+11  2.074812e+11
# 3            2. Các khoản tương đương tiền  5.403250e+10  2.772512e+11
# 4  II. Các khoản đầu tư tài chính ngắn hạn  5.409928e+10  8.737298e+10
#
#     Quý 1- 2022   Quý 2- 2022
# 0  1.851526e+12  1.634107e+12
# 1  4.061774e+11  5.391797e+11
# 2  2.442281e+11  3.801584e+11
# 3  1.619492e+11  1.590213e+11
# 4  1.513730e+11  2.416496e+11

# %%
#cdkt_20210930
sample_df['Số cuối kỳ'] = Q3_2021_to_Q2_2022['Quý 3- 2021']
cdkt_20210930 = sample_df.copy()
#cdkt_20211231
sample_df['Số cuối kỳ'] = Q3_2021_to_Q2_2022['Quý 4- 2021']
cdkt_20211231 = sample_df.copy()
#cdkt_20220331
sample_df['Số cuối kỳ'] = Q3_2021_to_Q2_2022['Quý 1- 2022']
cdkt_20220331 = sample_df.copy()
#cdkt_20220630
sample_df['Số cuối kỳ'] = Q3_2021_to_Q2_2022['Quý 2- 2022']
cdkt_20220630 = sample_df.copy()
cdkt_20210930.head()
# Out:
#                                        Chỉ tiêu Mã số    Số cuối kỳ Số đầu kỳ
# 0  A.Tài sản ngắn hạn (100=110+120+130+140+150)   100  8.892372e+11
# 1         I. Tiền và các khoản tương đương tiền   110  2.171378e+11
# 2                                       1. Tiền   111  1.631053e+11
# 3                 2. Các khoản tương đương tiền   112  5.403250e+10
# 4       II. Các khoản đầu tư tài chính ngắn hạn   120  5.409928e+10

# %% [markdown]
# **Quý 3, Quý 4 năm 2022; Quý 1, Quý 2 năm 2023**

# %%
Q3_2022_to_Q2_2023 = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/sample.xlsx',sheet_name='Q3-2022 to Q2-2023')
Q3_2022_to_Q2_2023.head()
# Out:
#                                    TÀI SẢN   Quý 3- 2022   Quý 4- 2022  \
# 0                      A- TÀI SẢN NGẮN HẠN  2.017894e+12  1.750033e+12
# 1    I. Tiền và các khoản tương đương tiền  6.245862e+11  4.154810e+11
# 2                                  1. Tiền  3.715674e+11  2.909810e+11
# 3            2. Các khoản tương đương tiền  2.530188e+11  1.245000e+11
# 4  II. Các khoản đầu tư tài chính ngắn hạn  2.826496e+11  1.400993e+11
#
#     Quý 1- 2023   Quý 2- 2023
# 0  1.690900e+12  1.779618e+12
# 1  3.777998e+11  3.776016e+11
# 2  2.692998e+11  2.086016e+11
# 3  1.085000e+11  1.690000e+11
# 4  1.200993e+11  1.200993e+11

# %%
#cdkt_20220930
sample_df['Số cuối kỳ'] = Q3_2022_to_Q2_2023['Quý 3- 2022']
cdkt_20220930 = sample_df.copy()
cdkt_20220930.head()
#cdkt_20221231
sample_df['Số cuối kỳ'] = Q3_2022_to_Q2_2023['Quý 4- 2022']
cdkt_20221231 = sample_df.copy()
cdkt_20221231.head()
#cdkt_20230331
sample_df['Số cuối kỳ'] = Q3_2022_to_Q2_2023['Quý 1- 2023']
cdkt_20230331 = sample_df.copy()
cdkt_20230331.head()
#cdkt_20230630
sample_df['Số cuối kỳ'] = Q3_2022_to_Q2_2023['Quý 2- 2023']
cdkt_20230630 = sample_df.copy()
cdkt_20230630.head()
# Out:
#                                        Chỉ tiêu Mã số    Số cuối kỳ Số đầu kỳ
# 0  A.Tài sản ngắn hạn (100=110+120+130+140+150)   100  1.779618e+12
# 1         I. Tiền và các khoản tương đương tiền   110  3.776016e+11
# 2                                       1. Tiền   111  2.086016e+11
# 3                 2. Các khoản tương đương tiền   112  1.690000e+11
# 4       II. Các khoản đầu tư tài chính ngắn hạn   120  1.200993e+11

# %% [markdown]
# **Quý 3, Quý 4 năm 2023; Quý 1, Quý 2 năm 2024**

# %%
Q3_2023_to_Q2_2024 = pd.read_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/sample.xlsx',sheet_name='Q3-2023 to Q2-2024')
Q3_2023_to_Q2_2024.head()
# Out:
#                                    TÀI SẢN  Quý 3 - 2023  Quý 4 - 2023  \
# 0                      A- TÀI SẢN NGẮN HẠN  1.844523e+12  1.596941e+12
# 1    I. Tiền và các khoản tương đương tiền  3.106216e+11  2.454164e+11
# 2                                  1. Tiền  2.186216e+11  1.222664e+11
# 3            2. Các khoản tương đương tiền  9.200000e+10  1.231500e+11
# 4  II. Các khoản đầu tư tài chính ngắn hạn  1.175000e+11  7.250000e+10
#
#    Quý 1 - 2024  Quý 2 - 2024
# 0  1.938824e+12  1.558343e+12
# 1  6.317979e+11  3.680502e+11
# 2  6.207979e+11  2.590502e+11
# 3  1.100000e+10  1.090000e+11
# 4  6.350000e+10  3.350000e+10

# %%
#cdkt_20230930
sample_df['Số cuối kỳ'] = Q3_2023_to_Q2_2024['Quý 3 - 2023']
cdkt_20230930 = sample_df.copy()
cdkt_20230930.head()
#cdkt_20231231
sample_df['Số cuối kỳ'] = Q3_2023_to_Q2_2024['Quý 4 - 2023']
cdkt_20231231 = sample_df.copy()
cdkt_20231231.head()
#cdkt_20240331
sample_df['Số cuối kỳ'] = Q3_2023_to_Q2_2024['Quý 1 - 2024']
cdkt_20240331 = sample_df.copy()
cdkt_20240331.head()
#cdkt_20240630
sample_df['Số cuối kỳ'] = Q3_2023_to_Q2_2024['Quý 2 - 2024']
cdkt_20240630 = sample_df.copy()
cdkt_20240630.head()
# Out:
#                                        Chỉ tiêu Mã số    Số cuối kỳ Số đầu kỳ
# 0  A.Tài sản ngắn hạn (100=110+120+130+140+150)   100  1.558343e+12
# 1         I. Tiền và các khoản tương đương tiền   110  3.680502e+11
# 2                                       1. Tiền   111  2.590502e+11
# 3                 2. Các khoản tương đương tiền   112  1.090000e+11
# 4       II. Các khoản đầu tư tài chính ngắn hạn   120  3.350000e+10

# %% [markdown]
# **Lưu vào file excel**

# %%
#Lưu vào file excel
cdkt_20210331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20210331.xlsx',index=False)
cdkt_20210630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20210630.xlsx',index=False)
cdkt_20210930.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20210930.xlsx',index=False)
cdkt_20211231.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20211231.xlsx',index=False)
cdkt_20220331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20220331.xlsx',index=False)
cdkt_20220630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20220630.xlsx',index=False)
cdkt_20220930.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20220930.xlsx',index=False)
cdkt_20221231.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20221231.xlsx',index=False)
cdkt_20230331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20230331.xlsx',index=False)
cdkt_20230630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20230630.xlsx',index=False)
cdkt_20230930.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20230930.xlsx',index=False)
cdkt_20231231.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20231231.xlsx',index=False)
cdkt_20240331.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20240331.xlsx',index=False)
cdkt_20240630.to_excel('/content/drive/MyDrive/CTCP Vận tải và xếp dỡ Hải An/Cân đối kế toán/cdkt_20240630.xlsx',index=False)
